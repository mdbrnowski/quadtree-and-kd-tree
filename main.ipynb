# %%
from visualization import QuadtreeVisualization
from geometry import Rectangle
from numpy.random import seed, uniform

# %%
seed(0)
points = list(zip(uniform(-2, 2, size=25), uniform(-2, 2, size=25)))
rectangle = Rectangle(-0.3, 1, -0.7, 0.5)

# %%
tree = QuadtreeVisualization(points)
tree.add_grid()
tree.find(rectangle)
tree.vis.show_gif(interval=1000)
